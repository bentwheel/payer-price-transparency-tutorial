# %% [markdown]
# # Transparency in Coverage Data with Python: Part 2
#
# Hello there! If you are starting with this notebook and have not yet checked out the [introductory notebook in this series]('./tic_start.ipynb'), please do that first. It won't take long, and you'll be better prepared for the content in this notebook.
#
# ## In-Network Rate Files
#
# As we left off at the end of the previous notebook, we had defined a parser function to handle TOC files. I've saved off that function in a separate Python file so we can import it, and start off where we left off from Part 1. Let's quickly confirm that it works, because we'll be using it to fetch in-network rates.

# %%
from tic_toc import parse_tic_toc

rps, infs, aafs = parse_tic_toc('./toc_file.json')
display(rps, infs, aafs)
# Out:
#                               plan_name plan_id_type     plan_id  \
# 0              BLUECHOICE ADVANTAGE_POS          EIN  52-6002033
# 1     BLUECHOICE HMO HDHP INTEG DED_HMO         HIOS  10207VA038
# 2     BLUECHOICE HMO HDHP INTEG DED_HMO         HIOS  28137MD037
# 3     BLUECHOICE HMO HDHP INTEG DED_HMO         HIOS  86052DC040
# 4    BLUECHOICE HMO HDHP NON INTDED_HMO         HIOS  10207VA038
# ..                                  ...          ...         ...
# 134           DHMO - BlueDental HMO_HMO          EIN  83-4713006
# 135           DHMO - BlueDental HMO_HMO          EIN  87-0787360
# 136               DHMO - Dental HMO_HMO          EIN  52-0348850
# 137               DHMO - Dental HMO_HMO          EIN  52-2064235
# 138               DHMO - Dental HMO_HMO          EIN  52-6047882
#
#     plan_market_type  reporting_structure_number reporting_entity_name  \
# 0              group                           0         CareFirst Inc
# 1         individual                           1         CareFirst Inc
# 2         individual                           1         CareFirst Inc
# 3         individual                           1         CareFirst Inc
# 4         individual                           2         CareFirst Inc
# ..               ...                         ...                   ...
# 134            group                           4         CareFirst Inc
# 135            group                           4         CareFirst Inc
# 136            group                           5         CareFirst Inc
# 137            group                           5         CareFirst Inc
# 138            group                           5         CareFirst Inc
#
#        reporting_entity_type
# 0    HEALTH INSURANCE ISSUER
# 1    HEALTH INSURANCE ISSUER
# 2    HEALTH INSURANCE ISSUER
# 3    HEALTH INSURANCE ISSUER
# 4    HEALTH INSURANCE ISSUER
# ..                       ...
# 134  HEALTH INSURANCE ISSUER
# 135  HEALTH INSURANCE ISSUER
# 136  HEALTH INSURANCE ISSUER
# 137  HEALTH INSURANCE ISSUER
# 138  HEALTH INSURANCE ISSUER
#
# [139 rows x 7 columns]
#                        description  \
# 0    Carefirst in-network HMO file
# 1    Carefirst in-network HMO file
# 2    Carefirst in-network HMO file
# 3    Carefirst in-network HMO file
# 4    Carefirst in-network HMO file
# ..                             ...
# 835  Carefirst in-network HMO file
# 836  Carefirst in-network HMO file
# 837  Carefirst in-network HMO file
# 838  Carefirst in-network HMO file
# 839  Carefirst in-network HMO file
#
#                                               location  \
# 0    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 1    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 2    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 3    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 4    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# ..                                                 ...
# 835  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 836  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 837  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 838  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 839  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
#
#      reporting_structure_number reporting_entity_name    reporting_entity_type
# 0                             0         CareFirst Inc  HEALTH INSURANCE ISSUER
# 1                             0         CareFirst Inc  HEALTH INSURANCE ISSUER
# 2                             0         CareFirst Inc  HEALTH INSURANCE ISSUER
# 3                             0         CareFirst Inc  HEALTH INSURANCE ISSUER
# 4                             0         CareFirst Inc  HEALTH INSURANCE ISSUER
# ..                          ...                   ...                      ...
# 835                           5         CareFirst Inc  HEALTH INSURANCE ISSUER
# 836                           5         CareFirst Inc  HEALTH INSURANCE ISSUER
# 837                           5         CareFirst Inc  HEALTH INSURANCE ISSUER
# 838                           5         CareFirst Inc  HEALTH INSURANCE ISSUER
# 839                           5         CareFirst Inc  HEALTH INSURANCE ISSUER
#
# [840 rows x 5 columns]
#                          description  \
# 0  Carefirst allowed amount HMO file
# 1  Carefirst allowed amount HMO file
# 2  Carefirst allowed amount HMO file
# 3  Carefirst allowed amount HMO file
# 4  Carefirst allowed amount HMO file
# 5  Carefirst allowed amount HMO file
#
#                                             location  \
# 0  https://mrf.carefirst.com/mrf-files/allowed-am...
# 1  https://mrf.carefirst.com/mrf-files/allowed-am...
# 2  https://mrf.carefirst.com/mrf-files/allowed-am...
# 3  https://mrf.carefirst.com/mrf-files/allowed-am...
# 4  https://mrf.carefirst.com/mrf-files/allowed-am...
# 5  https://mrf.carefirst.com/mrf-files/allowed-am...
#
#    reporting_structure_number reporting_entity_name    reporting_entity_type
# 0                           0         CareFirst Inc  HEALTH INSURANCE ISSUER
# 1                           1         CareFirst Inc  HEALTH INSURANCE ISSUER
# 2                           2         CareFirst Inc  HEALTH INSURANCE ISSUER
# 3                           3         CareFirst Inc  HEALTH INSURANCE ISSUER
# 4                           4         CareFirst Inc  HEALTH INSURANCE ISSUER
# 5                           5         CareFirst Inc  HEALTH INSURANCE ISSUER

# %% [markdown]
# ## Unique In-Network Rates Only
#
# In the last notebook, we discovered that while there are 140 x 6 = 840 unique File Location objects in the TOC file that refer to URLs containing In-Network Rates, that these 140 URLs are duplicated 6 times for each of the 6 `reporting_structure` objects in the TOC file.
#
# So, we only need the unqiue URLs. Let's get them now.

# %%
import pandas as pd

unique_infs = infs['location'].drop_duplicates()
display(pd.DataFrame(unique_infs))
# Out:
#                                               location
# 0    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 1    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 2    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 3    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 4    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# ..                                                 ...
# 135  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 136  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 137  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 138  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
# 139  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...
#
# [140 rows x 1 columns]

# %% [markdown]
# ## GET header Requests over HTTPS
#
# You may have heard that these in-network rate files can be quite large. Before we start going willy-nilly downloading them all, let's transmit a bunch of GET requests over HTTPS for just the request header - which will tell us a number of things about the file, including its size, in bytes.
#
# Let's *also* remember that payers have to pay egress charges for these downloads, so when we download these large files, we need to be mindful to not spam them with download requests - either intentionally or unintentionally. (An issue has already been raised on the CMS GitHub site concerning this very issue.)
#
# We're going to convert bytes to Megabytes (MB) by dividing the header value returned for the key `Content-length` by 1000^2. Then, we'll combine this list with the URLs and sort our URLs in order of smallest to largest.
#
# (This will take a moment to run as it is fetch the header content from sending GET requests over HTTPS for all 140 URLs)

# %%
import requests as rq

header_info = [rq.head(url).headers['Content-length'] for url in unique_infs]
header_info_mb = [ int(hi) / (1000**2) for hi in header_info]

unique_inf_urls = pd.DataFrame()
unique_inf_urls['location'] = unique_infs
unique_inf_urls['filesize'] = header_info_mb
unique_inf_urls = unique_inf_urls.sort_values(by=['filesize']).reset_index(drop=True)
display(unique_inf_urls)
# Out:
#                                               location   filesize
# 0    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...   0.211853
# 1    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...   0.211853
# 2    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...   0.211853
# 3    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...   0.211853
# 4    https://carefirstbcbs.mrf.bcbs.com/2022-08_690...   0.257835
# ..                                                 ...        ...
# 135  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  13.788947
# 136  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  21.501631
# 137  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  21.501631
# 138  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  21.501631
# 139  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  21.501631
#
# [140 rows x 2 columns]
# 0.211853

# %%
display(unique_inf_urls.tail(n=50))
# Out:
#                                               location   filesize
# 90   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  10.833255
# 91   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  10.833255
# 92   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.082750
# 93   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.082750
# 94   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.082750
# 95   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.082750
# 96   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.825912
# 97   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.825912
# 98   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.825912
# 99   https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.825912
# 100  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.911627
# 101  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.911627
# 102  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.911627
# 103  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  11.911627
# 104  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.441736
# 105  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.441736
# 106  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.441736
# 107  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.441736
# 108  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.612977
# 109  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.612977
# 110  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.612977
# 111  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.612977
# 112  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.674242
# 113  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.674242
# 114  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.674242
# 115  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.674242
# 116  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.909938
# 117  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.909938
# 118  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.909938
# 119  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.909938
# 120  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.918737
# 121  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.918737
# 122  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.918737
# 123  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.918737
# 124  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.946733
# 125  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.946733
# 126  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.946733
# 127  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  12.946733
# 128  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  13.037408
# 129  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  13.037408
# 130  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  13.037408
# 131  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  13.037408
# 132  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  13.788947
# 133  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  13.788947
# 134  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  13.788947
# 135  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  13.788947
# 136  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  21.501631
# 137  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  21.501631
# 138  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  21.501631
# 139  https://carefirstbcbs.mrf.bcbs.com/2022-08_690...  21.501631

# %% [markdown]
# ## Downloading to disk vs. Streaming
#
# Up until now, we have downloaded every file to disk before processing. However, some of these files are quite large, and when uncompressed, even larger. We can avoid downloading large files, instead by streaming them over HTTPS and through a gzip file connection, which uncompresses the stream and gives us the capability to parse.
#
# The `ijson` parser works unidirectionally, so there's no need to backtrack as long as we tell `ijson`'s parser exactly the JSON map items we're looking to mine out of the file up front. Thanks to the CMS standard that explicitly describes the files' structures, we're
#
# While uncompressing the stream on the fly takes a little longer, we can be certain to not having to worry about finding the disk space for all these giant files.

# %%
import urllib.request
import ijson
import gzip

ijson.use_float=True
ijson.multiple_values=True

# Start with the smallest filesize in our collection of URLs
url = unique_inf_urls['location'][139]
hdr = { 'Accept-encoding' : 'gzip' }

# Send HTTPS request
req = urllib.request.Request(url, headers=hdr)
response = urllib.request.urlopen(req)

# Stream compressed HTTPS data through open gzip file reader for decompression
uncompressed_stream = gzip.open(response, 'r')

# Stream decompressed output through ijson, searching for known items
parser = ijson.parse(uncompressed_stream)

base_rows = []
in_network_rows = pd.DataFrame()
for prefix, event, value in parser:
    if event == 'string' and '.' not in prefix:
        base_rows.append({prefix: value})
    if prefix == ('in_network.item') and event == 'start_map':
        in_network_row = []
        while ((prefix.startswith('in_network.item') and event != 'map_key') or (prefix == 'in_network.item' and event != 'end_map')):
            # Discard the next iteration
            prefix, event, value = next(parser)
            # The next item should be a primitive we want to keep - unless it is a negotiated-rates item
            prefix, event, value = next(parser)
            if prefix in ['in_network.item.negotiated_rates', 'in_network.item.bundled_codes', 'in_network.item.covered_services']:
                break
            # Add the dictionary to the list
            #print({prefix.replace('in_network.item.',''): value})
            in_network_row.extend([{prefix.replace('in_network.item.',''): value}])
        
        in_network_rows = in_network_rows.append({k: v for d in in_network_row for k, v in d.items()}, ignore_index=True)
        
        # At this point we should have a list of dicts we need to merge into a single dict,
        # then we add it to our rows list to be made into a dataframe at the end
        
uncompressed_stream.close()
display(in_network_rows)
# Out:
#      billing_code billing_code_type billing_code_type_version  \
# 0           69710               CPT                      2022
# 1           69710               CPT                      2022
# 2           69711               CPT                      2022
# 3           69711               CPT                      2022
# 4           69714               CPT                      2022
# ...           ...               ...                       ...
# 1070        78016               CPT                      2022
# 1071        78018               CPT                      2022
# 1072        78018               CPT                      2022
# 1073        78020               CPT                      2022
# 1074        78020               CPT                      2022
#
#                                         description       name  \
# 0     impltj/rplcmt emgnt bone cndj dev temporal bo    Surgery
# 1     impltj/rplcmt emgnt bone cndj dev temporal bo    Surgery
# 2        rmvl/rpr emgnt bone cndj dev temporal bone    Surgery
# 3        rmvl/rpr emgnt bone cndj dev temporal bone    Surgery
# 4         impltj oi implt skull perq attachment esp    Surgery
# ...                                             ...        ...
# 1070    thyroid carcinoma metastases img addl study  Radiology
# 1071    thyroid carcinoma metastases img whole body  Radiology
# 1072    thyroid carcinoma metastases img whole body  Radiology
# 1073            thyroid carcinoma metastases uptake  Radiology
# 1074            thyroid carcinoma metastases uptake  Radiology
#
#      negotiation_arrangement
# 0                     bundle
# 1                     bundle
# 2                     bundle
# 3                     bundle
# 4                     bundle
# ...                      ...
# 1070                  bundle
# 1071                  bundle
# 1072                  bundle
# 1073                  bundle
# 1074                  bundle
#
# [1075 rows x 6 columns]

# %%
in_network_details = pd.DataFrame({k: v for d in base_rows for k, v in d.items()}, index=[0])
display(in_network_details)
# Out:
#             reporting_entity_name    reporting_entity_type last_updated_on  \
# 0  CareFirst BlueCross BlueShield  health insurance issuer      2020-08-27
#
#   version
# 0   1.0.0

# %%
parser = ijson.parse(uncompressed_stream)

for prefix, event, value in parser:
    if prefix == 'reporting_entity_name':
        reporting_entity_name = value
    if prefix == 'reporting_entity_type':
        reporting_entity_type = value
    if prefix == 'last_updated_on':
        last_updated_on = value
    if prefix == 'version':
        version = value
        
print(reporting_entity_name, reporting_entity_type, last_updated_on, version)
# Out:
# ---------------------------------------------------------------------------
# IncompleteJSONError                       Traceback (most recent call last)
# <ipython-input-135-b72e6cc53737> in <module>
#       1 parser = ijson.parse(uncompressed_stream)
#       2
# ----> 3 for prefix, event, value in parser:
#       4     if prefix == 'reporting_entity_name':
#       5         reporting_entity_name = value
#
# IncompleteJSONError: parse error: premature EOF
#
#                      (right here) ------^
